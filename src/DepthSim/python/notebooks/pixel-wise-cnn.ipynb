# %%
import numpy as np
import matplotlib.pyplot as plt
import os
from scipy import misc
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import Flatten
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers.convolutional import Convolution2D
from keras.layers.convolutional import MaxPooling2D
from keras.layers import Activation
from keras.layers import Reshape



from keras.utils import np_utils
from keras import backend as K
import cv2
from sklearn.model_selection import train_test_split
K.set_image_dim_ordering('th')
# %matplotlib
# Out:
# /usr/local/lib/python2.7/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
img_height, img_width = 480,640
from keras.preprocessing import image
from itertools import izip

batch_size = 100
def hot_vectorize(x):
    zero_mask = x==0
    non_zero_mask = x!=0
    x[zero_mask] = 1
    x[non_zero_mask] = 0
    return x

labeldatagen = image.ImageDataGenerator(
        #preprocessing_function=applications.xception.preprocess_input,
        #preprocessing_function = random_crop,
        #zoom_range=.5,
        preprocessing_function = hot_vectorize,
        data_format="channels_first")

datagen = image.ImageDataGenerator(
        #preprocessing_function=applications.xception.preprocess_input,
        #preprocessing_function = random_crop,
        rescale =1/255.,
        #zoom_range=.5,
        data_format="channels_first")

flow_from_directory_params = {'target_size': (img_height,img_width),
                                  'color_mode': 'grayscale',
                                  'class_mode': None,
                                  'batch_size': batch_size}

flow_from_directory_params1 = {'target_size': (img_height,img_width),
                                  'color_mode': 'rgb',
                                  'class_mode': None,
                                  'batch_size': batch_size}

mask_generator = labeldatagen.flow_from_directory(
        directory="/media/drc/DATA/NYU_TEST/labels/",
        shuffle = False,
        **flow_from_directory_params
    )
'''
rgb_generator = datagen.flow_from_directory(
        directory="/media/drc/DATA/chris_labelfusion/logs_test/test_gan_sim/",
        **flow_from_directory_params
    )
normal_generator = datagen.flow_from_directory(
        directory="/media/drc/DATA/chris_labelfusion/logs_test/test_gan_sim/",
        **flow_from_directory_params
    )
'''
gt_generator = datagen.flow_from_directory(
        directory="/media/drc/DATA/NYU_TEST/train/",
        shuffle =False,
        **flow_from_directory_params1 
    )

train_generator =  izip(gt_generator, mask_generator)


plt.figure()
plt.imshow(np.reshape(mask_generator.next()[0],(img_height,img_width)))
plt.figure()
a=np.reshape(gt_generator.next()[0],(3,img_height,img_width))
a=np.swapaxes(a,0,2)
a=np.swapaxes(a,0,1)

plt.imshow(a)
# Out:
# Found 3989 images belonging to 1 classes.
# Found 3989 images belonging to 1 classes.

# %%
nputs = tf.placeholder(tf.float32, [batch_size, img_height, img_width, 1])
logits = inference(inputs)  # your outputs of shape [batch_size, 256, 256, 33] (no final softmax !!)
labels = tf.placeholder(tf.float32, [batch_size, img_height, img_width])  # your labels of shape [batch_size, 256, 256] and type int64

loss = sparse_softmax_cross_entropy_with_logits(logits, labels)

# %%
from keras.layers.convolutional import Conv2D
from keras.layers import *
from keras import Model
from keras import optimizers
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
import matplotlib.pyplot as plt
# %matplotlib nbagg

# %%
inputs = Input((3,img_height, img_width))

# %%
conv1 = Conv2D(6, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(inputs)
conv1 = Conv2D(6, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv1)
pool1 = MaxPooling2D(pool_size=(2, 2),data_format='channels_first')(conv1)

conv2 = Conv2D(12, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(pool1)
conv2 = Conv2D(12, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv2)
pool2 = MaxPooling2D(pool_size=(2, 2),data_format='channels_first')(conv2)

conv3 = Conv2D(24, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(pool2)
conv3 = Conv2D(24, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv3)
pool3 = MaxPooling2D(pool_size=(2, 2),data_format='channels_first')(conv3)

conv4 = Conv2D(48, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(pool3)
conv4 = Conv2D(48, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv4)
drop4 = Dropout(0.5)(conv4)
pool4 = MaxPooling2D(pool_size=(2, 2),data_format='channels_first')(drop4)

conv5 = Conv2D(96, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(pool4)
conv5 = Conv2D(96, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv5)
drop5 = Dropout(0.5)(conv5)

up6 = Conv2D(48, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(UpSampling2D(size = (2,2))(drop5))
merge6 = merge([drop4,up6], mode = 'concat', concat_axis = 0)
conv6 = Conv2D(48, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(merge6)
conv6 = Conv2D(48, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv6)

up7 = Conv2D(24, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(UpSampling2D(size = (2,2))(conv6))
merge7 = merge([conv3,up7], mode = 'concat', concat_axis = 0)
conv7 = Conv2D(24, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(merge7)
conv7 = Conv2D(24, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv7)

up8 = Conv2D(12, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(UpSampling2D(size = (2,2))(conv7))
merge8 = merge([conv2,up8], mode = 'concat', concat_axis = 0)
conv8 = Conv2D(12, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(merge8)
conv8 = Conv2D(12, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv8)

up9 = Conv2D(6, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(UpSampling2D(size = (2,2))(conv8))
merge9 = merge([conv1,up9], mode = 'concat', concat_axis = 0)
conv9 = Conv2D(6, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(merge9)
conv9 = Conv2D(6, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv9)
conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv9)
conv10 = Conv2D(1, 1, activation = 'sigmoid',data_format='channels_first')(conv9)

model = Model(input = inputs, output = conv10)
print model.summary()
model.compile(optimizer = optimizers.Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:23: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:28: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:33: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:38: UserWarning: The `merge` function is deprecated and will be removed after 08/2017. Use instead layers from `keras.layers.merge`, e.g. `add`, `concatenate`, etc.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:44: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("co..., inputs=Tensor("in...)`
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            (None, 3, 480, 640)  0
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 6, 480, 640)  168         input_5[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 6, 480, 640)  330         conv2d_139[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_21 (MaxPooling2D) (None, 6, 240, 320)  0           conv2d_140[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 12, 240, 320) 660         max_pooling2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 12, 240, 320) 1308        conv2d_141[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_22 (MaxPooling2D) (None, 12, 120, 160) 0           conv2d_142[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 24, 120, 160) 2616        max_pooling2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 24, 120, 160) 5208        conv2d_143[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_23 (MaxPooling2D) (None, 24, 60, 80)   0           conv2d_144[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 48, 60, 80)   10416       max_pooling2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 48, 60, 80)   20784       conv2d_145[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 48, 60, 80)   0           conv2d_146[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_24 (MaxPooling2D) (None, 48, 30, 40)   0           dropout_11[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 96, 30, 40)   41568       max_pooling2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 96, 30, 40)   83040       conv2d_147[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 96, 30, 40)   0           conv2d_148[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_21 (UpSampling2D) (None, 96, 60, 80)   0           dropout_12[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 48, 60, 80)   18480       up_sampling2d_21[0][0]
# __________________________________________________________________________________________________
# merge_21 (Merge)                (None, 48, 60, 80)   0           dropout_11[0][0]
#                                                                  conv2d_149[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 48, 60, 80)   20784       merge_21[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 48, 60, 80)   20784       conv2d_150[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_22 (UpSampling2D) (None, 48, 120, 160) 0           conv2d_151[0][0]
# __________________________________________________________________________________________________
# conv2d_152 (Conv2D)             (None, 24, 120, 160) 4632        up_sampling2d_22[0][0]
# __________________________________________________________________________________________________
# merge_22 (Merge)                (None, 24, 120, 160) 0           conv2d_144[0][0]
#                                                                  conv2d_152[0][0]
# __________________________________________________________________________________________________
# conv2d_153 (Conv2D)             (None, 24, 120, 160) 5208        merge_22[0][0]
# __________________________________________________________________________________________________
# conv2d_154 (Conv2D)             (None, 24, 120, 160) 5208        conv2d_153[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_23 (UpSampling2D) (None, 24, 240, 320) 0           conv2d_154[0][0]
# __________________________________________________________________________________________________
# conv2d_155 (Conv2D)             (None, 12, 240, 320) 1164        up_sampling2d_23[0][0]
# __________________________________________________________________________________________________
# merge_23 (Merge)                (None, 12, 240, 320) 0           conv2d_142[0][0]
#                                                                  conv2d_155[0][0]
# __________________________________________________________________________________________________
# conv2d_156 (Conv2D)             (None, 12, 240, 320) 1308        merge_23[0][0]
# __________________________________________________________________________________________________
# conv2d_157 (Conv2D)             (None, 12, 240, 320) 1308        conv2d_156[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_24 (UpSampling2D) (None, 12, 480, 640) 0           conv2d_157[0][0]
# __________________________________________________________________________________________________
# conv2d_158 (Conv2D)             (None, 6, 480, 640)  294         up_sampling2d_24[0][0]
# __________________________________________________________________________________________________
# merge_24 (Merge)                (None, 6, 480, 640)  0           conv2d_140[0][0]
#                                                                  conv2d_158[0][0]
# __________________________________________________________________________________________________
# conv2d_159 (Conv2D)             (None, 6, 480, 640)  330         merge_24[0][0]
# __________________________________________________________________________________________________
# conv2d_160 (Conv2D)             (None, 6, 480, 640)  330         conv2d_159[0][0]
# __________________________________________________________________________________________________
# conv2d_161 (Conv2D)             (None, 2, 480, 640)  110         conv2d_160[0][0]
# __________________________________________________________________________________________________
# conv2d_162 (Conv2D)             (None, 1, 480, 640)  3           conv2d_161[0][0]
# ==================================================================================================
# Total params: 246,041
# Trainable params: 246,041
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
model_checkpoint = ModelCheckpoint('unet.hdf5', monitor='loss',verbose=1, save_best_only=True)
print('Fitting model...')
model.fit_generator(train_generator, nb_epoch=100,steps_per_epoch=100, verbose=1, shuffle=True, callbacks=[model_checkpoint])
# Out:
# Fitting model...
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<itertools..., shuffle=True, verbose=1, steps_per_epoch=100, epochs=100, callbacks=[<keras.ca...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
# Epoch 1/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.6897 - acc: 0.8310
# Epoch 00001: loss improved from inf to 0.68970, saving model to unet.hdf5
# 100/100 [==============================] - 13s 133ms/step - loss: 0.6897 - acc: 0.8311
# Epoch 2/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.6667 - acc: 0.8668
# Epoch 00002: loss improved from 0.68970 to 0.66663, saving model to unet.hdf5
# 100/100 [==============================] - 10s 98ms/step - loss: 0.6666 - acc: 0.8669
# Epoch 3/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.6456 - acc: 0.8775- ETA: 0s - loss: 0.6462 - acc: 0.
# Epoch 00003: loss improved from 0.66663 to 0.64546, saving model to unet.hdf5
# 100/100 [==============================] - 10s 99ms/step - loss: 0.6455 - acc: 0.8776
# Epoch 4/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.6235 - acc: 0.8868
# Epoch 00004: loss improved from 0.64546 to 0.62343, saving model to unet.hdf5
# 100/100 [==============================] - 10s 99ms/step - loss: 0.6234 - acc: 0.8868
# Epoch 5/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.6077 - acc: 0.8880
# Epoch 00005: loss improved from 0.62343 to 0.60759, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.6076 - acc: 0.8881
# Epoch 6/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.5877 - acc: 0.8932
# Epoch 00006: loss improved from 0.60759 to 0.58763, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5876 - acc: 0.8931
# Epoch 7/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.5713 - acc: 0.8844
# Epoch 00007: loss improved from 0.58763 to 0.57124, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5712 - acc: 0.8844
# Epoch 8/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.5505 - acc: 0.8944
# Epoch 00008: loss improved from 0.57124 to 0.55041, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5504 - acc: 0.8944
# Epoch 9/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.5284 - acc: 0.8988
# Epoch 00009: loss improved from 0.55041 to 0.52832, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.5283 - acc: 0.8988
# Epoch 10/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.5068 - acc: 0.9028
# Epoch 00010: loss improved from 0.52832 to 0.50666, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.5067 - acc: 0.9028
# Epoch 11/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.4783 - acc: 0.9053
# Epoch 00011: loss improved from 0.50666 to 0.47799, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.4780 - acc: 0.9053
# Epoch 12/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.4398 - acc: 0.9107
# Epoch 00012: loss improved from 0.47799 to 0.43982, saving model to unet.hdf5
# 100/100 [==============================] - 10s 102ms/step - loss: 0.4398 - acc: 0.9107
# Epoch 13/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.4385 - acc: 0.8972
# Epoch 00013: loss improved from 0.43982 to 0.43842, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4384 - acc: 0.8972
# Epoch 14/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.4307 - acc: 0.8908
# Epoch 00014: loss improved from 0.43842 to 0.43058, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.4306 - acc: 0.8909
# Epoch 15/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.4054 - acc: 0.9049
# Epoch 00015: loss improved from 0.43058 to 0.40526, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.4053 - acc: 0.9050
# Epoch 16/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3945 - acc: 0.9006
# Epoch 00016: loss improved from 0.40526 to 0.39443, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.3944 - acc: 0.9006
# Epoch 17/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3836 - acc: 0.9013
# Epoch 00017: loss improved from 0.39443 to 0.38357, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.3836 - acc: 0.9012
# Epoch 18/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3765 - acc: 0.8980- ETA: 2s - lo
# Epoch 00018: loss improved from 0.38357 to 0.37646, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.3765 - acc: 0.8979
# Epoch 19/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3868 - acc: 0.8819- ETA: 0s - loss: 0.3867 - acc: 0.882
# Epoch 00019: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.3869 - acc: 0.8818
# Epoch 20/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3937 - acc: 0.8723
# Epoch 00020: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.3936 - acc: 0.8724
# Epoch 21/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3684 - acc: 0.8890
# Epoch 00021: loss improved from 0.37646 to 0.36834, saving model to unet.hdf5
# 100/100 [==============================] - 10s 102ms/step - loss: 0.3683 - acc: 0.8890
# Epoch 22/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3585 - acc: 0.8919
# Epoch 00022: loss improved from 0.36834 to 0.35844, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.3584 - acc: 0.8920
# Epoch 23/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3529 - acc: 0.8919
# Epoch 00023: loss improved from 0.35844 to 0.35282, saving model to unet.hdf5
# 100/100 [==============================] - 10s 102ms/step - loss: 0.3528 - acc: 0.8919
# Epoch 24/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3572 - acc: 0.8853
# Epoch 00024: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.3572 - acc: 0.8853
# Epoch 25/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3490 - acc: 0.8881- ETA: 0s - loss: 0.3498 - acc:
# Epoch 00025: loss improved from 0.35282 to 0.34885, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.3488 - acc: 0.8882
# Epoch 26/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3124 - acc: 0.9079
# Epoch 00026: loss improved from 0.34885 to 0.31239, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.3124 - acc: 0.9079
# Epoch 27/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3052 - acc: 0.9087
# Epoch 00027: loss improved from 0.31239 to 0.30525, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.3053 - acc: 0.9086
# Epoch 28/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3151 - acc: 0.8980
# Epoch 00028: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.3152 - acc: 0.8979
# Epoch 29/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3152 - acc: 0.8950
# Epoch 00029: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.3151 - acc: 0.8950
# Epoch 30/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3109 - acc: 0.8957- ETA: 1s - loss: 0.3113 -
# Epoch 00030: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.3109 - acc: 0.8956
# Epoch 31/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.3001 - acc: 0.8982
# Epoch 00031: loss improved from 0.30525 to 0.29994, saving model to unet.hdf5
# 100/100 [==============================] - 10s 104ms/step - loss: 0.2999 - acc: 0.8983
# Epoch 32/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2852 - acc: 0.9056
# Epoch 00032: loss improved from 0.29994 to 0.28514, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2851 - acc: 0.9056
# Epoch 33/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2715 - acc: 0.9076
# Epoch 00033: loss improved from 0.28514 to 0.27138, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2714 - acc: 0.9076
# Epoch 34/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2728 - acc: 0.9010
# Epoch 00034: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.2728 - acc: 0.9010
# Epoch 35/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2677 - acc: 0.9011
# Epoch 00035: loss improved from 0.27138 to 0.26775, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2678 - acc: 0.9011
# Epoch 36/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2760 - acc: 0.8977
# Epoch 00036: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2760 - acc: 0.8977
# Epoch 37/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2803 - acc: 0.8992
# Epoch 00037: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2802 - acc: 0.8992
# Epoch 38/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2862 - acc: 0.8950
# Epoch 00038: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.2861 - acc: 0.8950
# Epoch 39/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2741 - acc: 0.8985
# Epoch 00039: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2740 - acc: 0.8985
# Epoch 40/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2671 - acc: 0.9016- ETA: 3
# Epoch 00040: loss improved from 0.26775 to 0.26690, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2669 - acc: 0.9018
# Epoch 41/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2256 - acc: 0.9224
# Epoch 00041: loss improved from 0.26690 to 0.22544, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2254 - acc: 0.9224
# Epoch 42/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2287 - acc: 0.9212
# Epoch 00042: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2288 - acc: 0.9212
# Epoch 43/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2305 - acc: 0.9196
# Epoch 00043: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.2305 - acc: 0.9196
# Epoch 44/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2436 - acc: 0.9141
# Epoch 00044: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2436 - acc: 0.9141
# Epoch 45/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2404 - acc: 0.9153-
# Epoch 00045: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.2402 - acc: 0.9153
# Epoch 46/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2362 - acc: 0.9147- ETA: 1s - loss: 0.232
# Epoch 00046: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2364 - acc: 0.9146
# Epoch 47/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2506 - acc: 0.9072
# Epoch 00047: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2505 - acc: 0.9072
# Epoch 48/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2375 - acc: 0.9127
# Epoch 00048: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2375 - acc: 0.9127
# Epoch 49/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2317 - acc: 0.9151
# Epoch 00049: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2316 - acc: 0.9151
# Epoch 50/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2284 - acc: 0.9175
# Epoch 00050: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.2283 - acc: 0.9175
# Epoch 51/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2144 - acc: 0.9220
# Epoch 00051: loss improved from 0.22544 to 0.21437, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2144 - acc: 0.9220
# Epoch 52/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2102 - acc: 0.9246
# Epoch 00052: loss improved from 0.21437 to 0.21043, saving model to unet.hdf5
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2104 - acc: 0.9245
# Epoch 53/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2510 - acc: 0.9066- ETA: 0s - loss: 0.2511 - acc:
# Epoch 00053: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2510 - acc: 0.9066
# Epoch 54/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2517 - acc: 0.9054
# Epoch 00054: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2515 - acc: 0.9055
# Epoch 55/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2279 - acc: 0.9160
# Epoch 00055: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.2279 - acc: 0.9160
# Epoch 56/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2241 - acc: 0.9142
# Epoch 00056: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2241 - acc: 0.9142
# Epoch 57/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2366 - acc: 0.9124- ETA: 0s - loss: 0.2365 - acc: 0.91
# Epoch 00057: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2366 - acc: 0.9124
# Epoch 58/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2332 - acc: 0.9126
# Epoch 00058: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2333 - acc: 0.9126
# Epoch 59/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2586 - acc: 0.8982
# Epoch 00059: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2587 - acc: 0.8981
# Epoch 60/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2822 - acc: 0.8880
# Epoch 00060: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2822 - acc: 0.8880
# Epoch 61/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2582 - acc: 0.9046
# Epoch 00061: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2582 - acc: 0.9046
# Epoch 62/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2480 - acc: 0.9089
# Epoch 00062: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2482 - acc: 0.9089
# Epoch 63/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2599 - acc: 0.9031
# Epoch 00063: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2598 - acc: 0.9031
# Epoch 64/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2628 - acc: 0.8995
# Epoch 00064: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2628 - acc: 0.8995
# Epoch 65/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2505 - acc: 0.9036
# Epoch 00065: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2503 - acc: 0.9037
# Epoch 66/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2218 - acc: 0.9194
# Epoch 00066: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2218 - acc: 0.9194
# Epoch 67/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2204 - acc: 0.9201
# Epoch 00067: loss did not improve
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2204 - acc: 0.9200
# Epoch 68/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2431 - acc: 0.9065
# Epoch 00068: loss did not improve
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2432 - acc: 0.9064
# Epoch 69/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2415 - acc: 0.9048
# Epoch 00069: loss did not improve
# 100/100 [==============================] - 10s 103ms/step - loss: 0.2416 - acc: 0.9048
# Epoch 70/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2479 - acc: 0.9035
# Epoch 00070: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2479 - acc: 0.9035
# Epoch 71/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2420 - acc: 0.9054
# Epoch 00071: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2420 - acc: 0.9055
# Epoch 72/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2360 - acc: 0.9109
# Epoch 00072: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2360 - acc: 0.9109
# Epoch 73/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2294 - acc: 0.9132
# Epoch 00073: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2295 - acc: 0.9132
# Epoch 74/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2511 - acc: 0.9047
# Epoch 00074: loss did not improve
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2510 - acc: 0.9047
# Epoch 75/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2417 - acc: 0.9068
# Epoch 00075: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2418 - acc: 0.9068
# Epoch 76/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2540 - acc: 0.9011
# Epoch 00076: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2539 - acc: 0.9011
# Epoch 77/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2554 - acc: 0.9034
# Epoch 00077: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2554 - acc: 0.9034
# Epoch 78/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2598 - acc: 0.9003
# Epoch 00078: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2597 - acc: 0.9003
# Epoch 79/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2469 - acc: 0.9059
# Epoch 00079: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2469 - acc: 0.9059
# Epoch 80/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2370 - acc: 0.9110
# Epoch 00080: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2369 - acc: 0.9111
# Epoch 81/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.1971 - acc: 0.9285
# Epoch 00081: loss improved from 0.21043 to 0.19703, saving model to unet.hdf5
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1970 - acc: 0.9285
# Epoch 82/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2051 - acc: 0.9255
# Epoch 00082: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2052 - acc: 0.9254
# Epoch 83/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2072 - acc: 0.9239
# Epoch 00083: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2073 - acc: 0.9239
# Epoch 84/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2217 - acc: 0.9192- ETA: 2s - loss:
# Epoch 00084: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2219 - acc: 0.9191
# Epoch 85/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2178 - acc: 0.9208- ETA: 1s - loss: 0.2194
# Epoch 00085: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2178 - acc: 0.9208
# Epoch 86/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2191 - acc: 0.9182
# Epoch 00086: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2194 - acc: 0.9181
# Epoch 87/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2305 - acc: 0.9123
# Epoch 00087: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2304 - acc: 0.9123
# Epoch 88/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2167 - acc: 0.9180
# Epoch 00088: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2166 - acc: 0.9180
# Epoch 89/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2123 - acc: 0.9190
# Epoch 00089: loss did not improve
# 100/100 [==============================] - 10s 101ms/step - loss: 0.2122 - acc: 0.9191
# Epoch 90/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2100 - acc: 0.9211
# Epoch 00090: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.2099 - acc: 0.9211
# Epoch 91/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.1948 - acc: 0.9279
# Epoch 00091: loss improved from 0.19703 to 0.19476, saving model to unet.hdf5
# 100/100 [==============================] - 10s 103ms/step - loss: 0.1948 - acc: 0.9279
# Epoch 92/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.1977 - acc: 0.9274
# Epoch 00092: loss did not improve
# 100/100 [==============================] - 10s 102ms/step - loss: 0.1980 - acc: 0.9272
# Epoch 93/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2299 - acc: 0.9114
# Epoch 00093: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2300 - acc: 0.9113
# Epoch 94/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2304 - acc: 0.9110
# Epoch 00094: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2303 - acc: 0.9110
# Epoch 95/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2101 - acc: 0.9198
# Epoch 00095: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2101 - acc: 0.9198
# Epoch 96/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2073 - acc: 0.9183
# Epoch 00096: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2073 - acc: 0.9183
# Epoch 97/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2228 - acc: 0.9151-
# Epoch 00097: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2228 - acc: 0.9151
# Epoch 98/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2202 - acc: 0.9147
# Epoch 00098: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2204 - acc: 0.9146
# Epoch 99/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2476 - acc: 0.9004
# Epoch 00099: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2478 - acc: 0.9003
# Epoch 100/100
#  99/100 [============================>.] - ETA: 0s - loss: 0.2659 - acc: 0.8935
# Epoch 00100: loss did not improve
# 100/100 [==============================] - 10s 100ms/step - loss: 0.2657 - acc: 0.8936

# %%
test = train_generator.next()
X_Test = test[0][0:10]
Y_Test = test[1][0:10]
imgs_mask_test = model.predict_on_batch(X_Test)

# %%
# %matplotlib nbagg
index = np.random.randint(3)
img = np.reshape(imgs_mask_test[4],(img_height,img_width))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e4eee3895dff> in <module>()
#       1 get_ipython().magic(u'matplotlib nbagg')
# ----> 2 index = np.random.randint(3)
#       3 img = np.reshape(imgs_mask_test[4],(img_height,img_width))
#       4 plt.imshow(img)
#
# NameError: name 'np' is not defined

# %%
# %matplotlib inline
img = np.reshape(Y_Test[0],(img_height,img_width))
plt.imshow(img)

# %%
train = train_generator.next()
X = train[0]
Y = train[1]
inputs = Input((1,img_height, img_width))

# %%
conv1 = Conv2D(32, 5, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(inputs)

conv2 = Conv2D(64, 5, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv1)

conv3 = Conv2D(32, 5, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv2)

conv4 = Conv2D(16, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv3)
#drop4 = Dropout(0.5)(conv4)

conv5 = Conv2D(4, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv4)

conv6 = Conv2D(1, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal',data_format='channels_first')(conv5)
#drop5 = Dropout(0.5)(conv5)

model1 = Model(input = inputs, output = conv6)
print model1.summary()
model1.compile(optimizer = optimizers.Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1, 480, 640)       0
# _________________________________________________________________
# conv2d_85 (Conv2D)           (None, 32, 480, 640)      832
# _________________________________________________________________
# conv2d_86 (Conv2D)           (None, 64, 480, 640)      51264
# _________________________________________________________________
# conv2d_87 (Conv2D)           (None, 32, 480, 640)      51232
# _________________________________________________________________
# conv2d_88 (Conv2D)           (None, 16, 480, 640)      4624
# _________________________________________________________________
# conv2d_89 (Conv2D)           (None, 4, 480, 640)       580
# _________________________________________________________________
# conv2d_90 (Conv2D)           (None, 1, 480, 640)       37
# =================================================================
# Total params: 108,569
# Trainable params: 108,569
# Non-trainable params: 0
# _________________________________________________________________
# None
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:15: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("co..., inputs=Tensor("in...)`
#   from ipykernel import kernelapp as app

# %%
model_checkpoint = ModelCheckpoint('unet.hdf5', monitor='loss',verbose=1, save_best_only=True)
print('Fitting model...')
model1.fit_generator(train_generator, steps_per_epoch=100,nb_epoch=10, verbose=1, shuffle=True, callbacks=[model_checkpoint])
# Out:
# Fitting model...
# Epoch 1/10
#   1/100 [..............................] - ETA: 13s - loss: 0.3969 - acc: 0.8304
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<itertools..., shuffle=True, verbose=1, steps_per_epoch=100, epochs=10, callbacks=[<keras.ca...)`
#   This is separate from the ipykernel package so we can avoid doing imports until
#  99/100 [============================>.] - ETA: 0s - loss: 0.3890 - acc: 0.8321
# Epoch 00001: loss improved from inf to 0.38894, saving model to unet.hdf5
# 100/100 [==============================] - 10s 100ms/step - loss: 0.3889 - acc: 0.8322
# Epoch 2/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3845 - acc: 0.8345
# Epoch 00002: loss improved from 0.38894 to 0.38439, saving model to unet.hdf5
# 100/100 [==============================] - 10s 97ms/step - loss: 0.3844 - acc: 0.8345
# Epoch 3/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3850 - acc: 0.8282
# Epoch 00003: loss did not improve
# 100/100 [==============================] - 10s 97ms/step - loss: 0.3851 - acc: 0.8281
# Epoch 4/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3777 - acc: 0.8301
# Epoch 00004: loss improved from 0.38439 to 0.37768, saving model to unet.hdf5
# 100/100 [==============================] - 10s 98ms/step - loss: 0.3777 - acc: 0.8301
# Epoch 5/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3708 - acc: 0.8475- ETA: 1s - loss: 0.
# Epoch 00005: loss improved from 0.37768 to 0.37074, saving model to unet.hdf5
# 100/100 [==============================] - 10s 98ms/step - loss: 0.3707 - acc: 0.8476
# Epoch 6/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3437 - acc: 0.8569
# Epoch 00006: loss improved from 0.37074 to 0.34374, saving model to unet.hdf5
# 100/100 [==============================] - 10s 98ms/step - loss: 0.3437 - acc: 0.8569
# Epoch 7/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3555 - acc: 0.8448
# Epoch 00007: loss did not improve
# 100/100 [==============================] - 10s 98ms/step - loss: 0.3555 - acc: 0.8447
# Epoch 8/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3555 - acc: 0.8361- ETA: 1s - loss: 0.
# Epoch 00008: loss did not improve
# 100/100 [==============================] - 10s 98ms/step - loss: 0.3554 - acc: 0.8361
# Epoch 9/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3503 - acc: 0.8382
# Epoch 00009: loss did not improve
# 100/100 [==============================] - 10s 99ms/step - loss: 0.3502 - acc: 0.8382
# Epoch 10/10
#  99/100 [============================>.] - ETA: 0s - loss: 0.3471 - acc: 0.8389
# Epoch 00010: loss did not improve
# 100/100 [==============================] - 10s 98ms/step - loss: 0.3470 - acc: 0.8389

# %%
test = train_generator.next()
X_Test = test[0][0:50]
Y_Test = test[1][0:50]

# %%
np.shape(X_Test),np.shape(imgs_mask_test)
# Out:
# ((1, 1, 480, 640), (1, 1, 480, 640))

# %%
imgs_mask_test = model1.predict_on_batch(X_Test)

# %%
# %matplotlib inline

# %%
index = np.random.randint(10)
img = np.reshape(imgs_mask_test,(img_height,img_width))
plt.imshow(img)
