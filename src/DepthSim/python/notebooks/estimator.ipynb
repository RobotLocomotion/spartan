# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from scipy import misc
import numpy as np
from keras import applications
from keras import layers
from keras import models
from keras import optimizers
from keras.preprocessing import image
import numpy as np
import tensorflow as tf
import os
import shutil
from dlutils import plot_image_batch_w_labels
from common import util
# %matplotlib nbagg

#from utils.image_history_buffer import ImageHistoryBuffer

# %%
def refiner_network(input_image_tensor):
   

    def resnet_block(input_features, nb_features=64, nb_kernel_rows=3, nb_kernel_cols=3):
        """
        A ResNet block with two `nb_kernel_rows` x `nb_kernel_cols` convolutional layers,
        each with `nb_features` feature maps.

        See Figure 6 in https://arxiv.org/pdf/1612.07828v1.pdf.

        :param input_features: Input tensor to ResNet block.
        :return: Output tensor from ResNet block.
        """
        y = layers.Convolution2D(nb_features, nb_kernel_cols, padding='same')(input_features)
        y = layers.Activation('relu')(y)
        y = layers.Convolution2D(nb_features, nb_kernel_rows, padding='same')(y)

        y = layers.add([input_features, y])
        return layers.Activation('relu')(y)

    x = layers.Convolution2D(64, (3, 3), padding='same', activation='relu')(input_image_tensor)

    # the output is passed through 4 ResNet blocks
    for _ in range(3):
        x = resnet_block(x)

    return layers.Convolution2D(1, (1, 1), padding='same', activation='tanh')(x)

# %%
def refiner_network(input_image_tensor):
   

    def resnet_block(input_features, nb_features=64, nb_kernel_rows=7, nb_kernel_cols=7):
        """
        A ResNet block with two `nb_kernel_rows` x `nb_kernel_cols` convolutional layers,
        each with `nb_features` feature maps.

        See Figure 6 in https://arxiv.org/pdf/1612.07828v1.pdf.

        :param input_features: Input tensor to ResNet block.
        :return: Output tensor from ResNet block.
        """
        y = layers.Convolution2D(nb_features, nb_kernel_cols, padding='same')(input_features)
        y = layers.Activation('relu')(y)
        y = layers.Convolution2D(nb_features, nb_kernel_rows, padding='same')(y)

        y = layers.add([input_features, y])
        return layers.Activation('relu')(y)

    x = layers.Convolution2D(64, (3, 3), padding='same', activation='relu')(input_image_tensor)

    # the output is passed through 4 ResNet blocks
    for _ in range(10):
        x = resnet_block(x)

    return layers.Convolution2D(1, (1, 1), padding='same', activation='tanh')(x)

# %%
def setup_refiner(refiner_model_path,img_height=100,img_width =100,img_channels = 1):
    def self_regularization_loss(y_true, y_pred):
        delta = 0.0001  # FIXME: need to figure out an appropriate value for this
        return tf.multiply(delta, tf.reduce_sum(tf.abs(y_pred - y_true)))
    synthetic_image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
    refined_image_tensor = refiner_network(synthetic_image_tensor)
    refined_or_real_image_tensor = layers.Input(shape=(img_height, img_width, img_channels))
    refiner_model = models.Model(input=synthetic_image_tensor, output=refined_image_tensor, name='refiner')
    refiner_model.load_weights(refiner_model_path)
    sgd = optimizers.SGD(lr=0.001)
    refiner_model.compile(optimizer=sgd, loss=self_regularization_loss)
    return refiner_model

# %%
def random_crop(x,width_x,offset_x,width_y,offset_y,denom=1000.):
    #x =x/denom
    #x -= 0.5
    #x *= 2.
    lowx = np.random.randint(width_x)+offset_x
    highx = lowx + 100
    lowy = np.random.randint(width_y)+offset_y
    highy = lowy + 100
    return x[lowx:highx,lowy:highy]

# %%
img_height, img_width = 240,240
from keras.preprocessing import image

datagen = image.ImageDataGenerator(
        #preprocessing_function=applications.xception.preprocess_input,
        #preprocessing_function = random_crop,
        rescale =1/1000.,
        #zoom_range=.5,
        data_format="channels_last")

flow_from_directory_params = {'target_size': (img_height,img_width),
                                  'color_mode': 'grayscale',
                                  'class_mode': None,
                                  'batch_size': 1}

synthetic_generator = datagen.flow_from_directory(
        directory="/media/drc/DATA/chris_labelfusion/logs_test/test_gan_sim/",
        **flow_from_directory_params
    )
# Out:
# Found 3998 images belonging to 1 classes.

# %%
plt.imshow(np.reshape(synthetic_generator.next(),(img_height,img_width)))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dest = "/media/drc/DATA/chris_labelfusion/CORL2017/object_database/"
for i in os.listdir(dest+"gtdepth/"):
    im = misc.imread(dest+"gtdepth/"+i)
    tokens = i.split("_")
    num = tokens[0]
    date = tokens[1]
    mask = im == 0
    rgb = misc.imread(dest+"rgb/"+num+"_"+date+"_rgb.png") 
    depth = misc.imread(dest+"depth/"+num+"_"+date+"_depth.png") 
    rgb[mask]=0
    depth[mask]=0
    misc.imsave(dest+"mask_rgb/"+num+"_"+date+"_rgb.png",rgb)
    misc.imsave(dest+"mask_depth/"+num+"_"+date+"_depth.png",depth)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   if __name__ == '__main__':
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:12: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# ...

# %%
dir1 = "/media/drc/DATA/chris_labelfusion/CORL2017/object_database/normal/"
plt.imshow(misc.imread(dir1+np.random.choice(os.listdir(dir1))))
#plt.imshow(misc.imread(dir1+"depth/0000000001_2017-06-15-73_depth.png"))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# <img src="data:image/png;base64,..." width="640">

# %%
def random_crops_dataset():
    sim = "/media/drc/DATA/chris_labelfusion/logs_test/test_gan_sim/train_log/"
    real = "/media/drc/DATA/chris_labelfusion/logs_test/test_gan/train_real/"
    target = "/media/drc/DATA/chris_labelfusion/CORL2017/gan_data_tmp/"
    #os.makedirs(target)    
    target_sim = target+"sim/train/"
    target_real = target+"real/train/"
    #os.makedirs(target_sim,0755)    
    #os.makedirs(target_real,0755)
    count = 0
    for s,r in zip(os.listdir(sim),os.listdir(real)):
        denom = 1.
        for i in range(10):
            s_x = random_crop(x=misc.imread(sim+s),offset_x=100,offset_y=100,width_x=200,width_y=300,denom=denom)
            r_x = random_crop(x=misc.imread(real+r),offset_x=100,offset_y=100,width_x=200,width_y=300,denom=denom)
            misc.imsave(target_sim+str(count)+"-"+s,s_x)
            misc.imsave(target_real+str(count)+"-"+r,r_x)
            count+=1
        if count%1000==0 and count >1000:
            print count

# %%
plt.imshow(predict_image(model,test/1.))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import os,random
def get_random_pair(directory ="/media/drc/DATA/chris_labelfusion/CORL2017/gan_mask/"):
    dir1= directory+"real/mask_depth/"
    dir2 = directory+"sim/gtdepth/"
    real = random.choice(os.listdir(dir1))
    tokens = real.split("_")
    sim = tokens[0]+"_"+tokens[1]+"_depth_ground_truth.png"
    return misc.imread(dir1+real),misc.imread(dir2+sim)

# %%
def invert_mapping(img):
    img = np.copy(img)
    img = img/ 2.
    img+= 0.5
    img =img* 255.
    return img

# %%
def predict_image(model,img):
    h,w = 224,224
    img = misc.imresize(img,(224,224))
    img =img/ 255.
    img-= 0.5
    img *= 2.
    #img=img/1000.
    return np.reshape(model.predict(np.reshape(img,(1,h,w,1))),(h,w))

# %%
def plot_random_pair(model,directory ="/media/drc/DATA/chris_labelfusion/CORL2017/gan_mask/"):
    real,sim = get_random_pair(directory)
    gen = predict_image(model,sim)
    sim  = misc.imresize(sim,(224,224))
    real  = misc.imresize(real,(224,224))
    plt.figure()
    plt.subplot(131)
    plt.imshow(sim)
    plt.subplot(132)
    plt.imshow(real)
    plt.subplot(133)
    plt.imshow(invert_mapping(gen))

# %%
plot_random_pair(model)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:3: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:4: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   after removing the cwd from sys.path.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# ...

# %%
model  = setup_refiner("/home/drc/Chris/SimGAN/cache/refiner_model_step_9500.h5",img_height=224,img_width=224)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:8: UserWarning: Update your `Model` call to the Keras 2 API: `Model(outputs=Tensor("co..., name="refiner", inputs=Tensor("in...)`

# %%
import os # could use color label masks instead but you got rid of them
base ="/media/drc/DATA1/chris_labelfusion/CORL2017/logs_test/"
search = "/media/drc/DATA1/chris_labelfusion/CORL2017/gan_data/sim/train/"
target = "/media/drc/DATA1/chris_labelfusion/CORL2017/gan_data/real/train/"
count=0
for i in os.listdir(search):
    try:
        num = int(i.split("_")[0])
        date = i.split("_")[1]
        s = search+str(num).zfill(10) +"_"+date+"_depth_ground_truth.png"
        r = base+date+"/images/" +str(num).zfill(10) +"_depth.png"
        count=0
        if len(np.nonzero(simage))>0 and len(np.nonzero(image))>0:
            simage = misc.imread(s)
            image = misc.imread(r)
            x1,x2,y1,y2 = util.bounding_box(simage,100)
            #misc.imsave(target+str(num).zfill(10) +"_"+date+"_depth.png",image[x1:x2,y1:y2])
            misc.imsave(search+str(num).zfill(10) +"_"+date+"_depth_ground_truth.png",simage[x1:x2,y1:y2])
        else: print r,s,"here"
    except ValueError:
        print r,s,"error"
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:14: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: `imsave` is deprecated!
# `imsave` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imwrite`` instead.
# /media/drc/DATA1/chris_labelfusion/CORL2017/logs_test/2017-06-14-57/images/0000000727_depth.png /media/drc/DATA1/chris_labelfusion/CORL2017/gan_data/sim/train/0000000727_2017-06-14-57_depth_ground_truth.png error
# ...

# %%
size =100
for i in range(1,5):
    for j in range(1,4):
        print size*i,size*i+size,size*j,size*j+size
        plt.imshow(d[200:400,300:500])
# Out:
# 100 200 100 200
# 100 200 200 300
# 100 200 300 400
# 200 300 100 200
# 200 300 200 300
# 200 300 300 400
# 300 400 100 200
# 300 400 200 300
# 300 400 300 400
# 400 500 100 200
# 400 500 200 300
# 400 500 300 400

# %%
path = "/media/drc/DATA/chris_labelfusion/logs_test/2017-06-16-15/images/"

# %%
plt.imshow()

# %%
from skimage import filter

# %%
def corrupt_image():
    d,c,s,r,n,g = util.get_images(np.random.randint(4000),10,path)
    normal_z =  filter.gaussian_filter(util.convert_rgb_normal(n)[:,:,2],sigma=1)
    mask = normal_z < .2
    g1 = np.copy(g)
    g1[mask] = 0
    plt.figure()
    plt.imshow(g1)
    plt.figure()
    plt.imshow(d)
    plt.figure()
    plt.imshow(g)

corrupt_image()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
d,c,s,r,n,g = util.get_images(2000,10,path)

# %% [markdown]
# ## The Data we have

# %%
plt.rcParams.update({'font.size': 5})
fig = plt.figure()
a=fig.add_subplot(3,2,1)
imgplot = plt.imshow(d)
a.set_title('Depth')
a=fig.add_subplot(3,2,3)
imgplot = plt.imshow(c)
a.set_title('RGB')
a=fig.add_subplot(3,2,6)
imgplot = plt.imshow(r)
a.set_title('Albedo')
a=fig.add_subplot(3,2,4)
imgplot = plt.imshow(s)
a.set_title('Shading')
a=fig.add_subplot(3,2,2)
imgplot = plt.imshow(g)
a.set_title('Ground Truth Depth')
a=fig.add_subplot(3,2,5)
imgplot = plt.imshow(n)
a.set_title('Ground Truth Normal')
plt.show()

# %%
imgplot = plt.imshow(misc.imresize(d,(100,100)))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">

# %%
g_resize = misc.imresize(g,(100,100))
imgplot = plt.imshow(misc.imresize(g_resize,(100,100)))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.

# %%
g_resize=g_resize/float(np.max(g_resize))*2-1

# %%
sim_gan_low_dim = np.reshape((model.predict(x=np.reshape(g_resize,(1,100,100,1)))),(100,100))
plt.imshow(sim_gan_low_dim)

# %%
drill = np.reshape((model.predict(x=np.reshape(imm,(1,100,100,1)))),(100,100))
drill[drill<0]=0
plt.imshow(drill)
# Out:
# -----------------------------------------------------------
# NameError                 Traceback (most recent call last)
# <ipython-input-14-3be554627911> in <module>()
# ----> 1 drill = np.reshape((model.predict(x=np.reshape(imm,(1,100,100,1)))),(100,100))
#       2 drill[drill<0]=0
#       3 plt.imshow(drill)
#
# NameError: name 'imm' is not defined

# %%
imm =misc.imread("/media/drc/DATA1/chris_labelfusion/CORL2017/drill/0000001288depth_ground_truth.png")
x_low,x_high,y_low,y_high = bounding_box(imm,size =100)
imm=imm.astype(np.float)
imm=imm/np.max(imm)*2-1
imm[imm==0]=np.NaN
imm = imm[x_low:x_high,y_low:y_high]
plt.imshow(imm)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="704.6666666666666">

# %%
imm =misc.imread("/media/drc/DATA1/chris_labelfusion/CORL2017/drill/0000001288depth_ground_truth.png")
x_low,x_high,y_low,y_high = bounding_box(imm,size =100)
imm=imm.astype(np.float)
imm=imm/np.max(imm)*2-1
imm[imm==0]=np.NaN
imm = imm[x_low:x_high,y_low:y_high]
plt.imshow(imm)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">

# %%
im2 =misc.imread("/media/drc/DATA1/chris_labelfusion/CORL2017/logs_test/2017-06-13-08/images/0000000378depth_ground_truth.png", mode="I",flatten=True)
im2_resize = misc.imresize(im2,(100,100))
im2_resize = im2_resize/float(np.max(im2_resize))
plt.imshow(im2_resize)
clb = plt.colorbar()
clb.ax.set_title('Depth delta (m)')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,u'Depth delta (m)')

# %%
im2_d+=(0-np.min(im2_d))
im2_d = im2_d/float(np.max(im2_d))

# %%
imgplot = plt.imshow(im2_d)
clb = plt.colorbar()
clb.ax.set_title('Depth delta (m)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,u'Depth delta (m)')

# %%
im2_d = np.reshape((model.predict_on_batch(x=np.reshape(im2_resize,(1,100,100,1)))),(100,100))
imgplot = plt.imshow(im2_d)
clb = plt.colorbar()
clb.ax.set_title('Depth delta (m)')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,u'Depth delta (m)')

# %%
g_resize = misc.imresize(g,(100,100))
g_resize = g_resize/float(np.max(g_resize))
g_d = np.reshape((model.predict(x=np.reshape(g_resize,(1,100,100,1)))),(100,100))
fig = plt.figure()
a=fig.add_subplot(3,1,1)
imgplot = plt.imshow(misc.imresize(d,(100,100)))
a.set_title('real')
a=fig.add_subplot(3,2,3)
imgplot = plt.imshow(g_d)
a.set_title('generated')
a=fig.add_subplot(3,2,2)
imgplot = plt.imshow(g_resize)
a.set_title('synthetic')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
#   """Entry point for launching an IPython kernel.
# <img src="data:image/png;base64,..." width="640">
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:6: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# Text(0.5,1,u'synthetic')

# %%
plt.imshow(d-g)
clb = plt.colorbar()
clb.ax.set_title('Depth delta (m)')

# %%
from scipy import ndimage as ndi
from skimage import filter
from skimage import color
from skimage import io
rg = color.rgb2gray(r)
rg = ndi.gaussian_filter(rg,4)
edges1 = filter.canny(rg)
edges2 = filter.canny(rg,sigma =6)
plt.imshow(edges1)
plt.imshow(edges2+d*.001)

# %% [markdown]
# # other data to try
#
#     can we get raw ir image?
#     derivative of ground truth depth RGB, sharp discontinuites not captured by normal angle

# %% [markdown]
# ## Where do the depth values differ

# %%
d1= np.copy(d)
gt1 =np.copy(g)
mask = create_depth_mask(gt1,0,1300)
d1[~mask]=0
gt1[~mask]=0
plt.imshow(d1-gt1)

# %%
#c[~mask]=0
plt.imshow(g)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Lets try predicting binary depth return given intrinsic intensities

# %%
plt.imshow(gen_image(g,gnb,d,g,n,c))

# %%
plt.imshow(np.log(gen_image(g,model_lr,d,g,n,c)))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
plt.imshow(np.log(d))
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log
#   """Entry point for launching an IPython kernel.

# %%
def gen_image(img, model,depth,gtdepth,normal,rgb):
    img = np.copy(img)
    for i in range(np.shape(img)[0]):
        for j in range(np.shape(img)[1]):
            prob = model.predict_proba([feature_from_images([i,j],depth[i,j],gtdepth[i,j],normal[i,j],rgb[i,j])])[0][0]
            img[i,j] = 0 if np.random.rand()< prob else img[i,j]
    return img

# %%
def feature_from_images(index,depth,gtdepth,normal,rgb):
    lateraly = index[0]/480.
    lateralx = index[1]/640.
    depth_pix = gtdepth/3000.
    normal = util.convert_rgb_normal(normal)[2] #add features like neighbor boundary, rgb
    return [lateralx,lateraly,depth_pix,normal]

# %%
def load_imgs(depth,gtdepth,normal,rgb):
    return misc.imread(depth),misc.imread(gtdepth),misc.imread(normal),misc.imread(rgb)

# %%
def labeled_data(path_gt,path_normal,path_rgb,path_depth,iterations = 1000,samples_per_image=100):
    x = [] #do larger box around objects but cant use those features
    y = []
    gt_list = os.listdir(path_gt)
    for i in range(iterations):
        gtdepth = np.random.choice(gt_list)
        tokens = gtdepth.split("_")
        normal = path_normal + tokens[0]+"_"+tokens[1]+"_normal_ground_truth.png"
        rgb = path_rgb + tokens[0]+"_"+tokens[1]+"_rgb.png"
        depth = path_depth + tokens[0]+"_"+tokens[1]+"_depth.png"
        gtdepth = path_gt +gtdepth
        depth,gtdepth,normal,rgb =load_imgs(depth,gtdepth,normal,rgb)
        for j in range(samples_per_image):
            #propose samples
            try:
                availible = gtdepth!=0
                nmd = np.argwhere(np.logical_and(availible, depth==0))#future region around
                md = np.argwhere(np.logical_and(availible, depth!=0))#future region around
                #create samples
                index_nmd = nmd[np.random.choice(np.shape(nmd)[0])]
                index_md = md[np.random.choice(np.shape(md)[0])]
                x.append(feature_from_images(index_nmd,depth[index_nmd[0],index_nmd[1]],gtdepth[index_nmd[0],index_nmd[1]],normal[index_nmd[0],index_nmd[1]],rgb[index_nmd[0],index_nmd[1]]))
                x.append(feature_from_images(index_md,depth[index_md[0],index_md[1]],gtdepth[index_md[0],index_md[1]],normal[index_md[0],index_md[1]],rgb[index_md[0],index_md[1]]))
                y.append(1)
                y.append(0)
            except(ValueError):
                print "value error"
    x,y = np.array(x),np.array(y)
    return x,y

# %%
base = "/media/drc/DATA/chris_labelfusion/CORL2017/object_database/"
x,y = labeled_data(base+"gtdepth/",base+"normal/",base+"rgb/",base+"depth/")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# value error
# ...

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x,y)
# Out:
# GaussianNB(priors=None)

# %%
from sklearn import linear_model
model_lr = linear_model.LogisticRegression(solver = 'sag',max_iter=1000)

# %%
model_lr.fit(x,y)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=1000, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='sag', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
base = "/media/drc/DATA/chris_labelfusion/CORL2017/object_database/"
x_test,y_test = labeled_data(base+"gtdepth/",base+"normal/",base+"rgb/",base+"depth/",20,100)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
gnb.score(x_test,y_test)
# Out:
# 0.7085

# %%
from sklearn.metrics import classification_report
print(classification_report(gnb.predict(x_test), y_test))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.76      0.69      0.72      2206
#           1       0.66      0.73      0.69      1794
#
# avg / total       0.71      0.71      0.71      4000

# %%
from matplotlib import cm
plt.imshow(d[250:278,250:278])
clb = plt.colorbar()
clb.ax.set_title('Depth (m)')
 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
def test(path,start=1,end=10,bounds=[100,400,100,500],file_digits=10):
    x = []
    num_pos=0
    for i in range(start,end+1):
        d,n,gt = get_images_short(i,file_digits,path)
        pos = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]==0)   
        data = map(lambda x: n[x[0],x[1]],pos)
        x.extend(data)        
    return np.array(x)
x=test(path,1,2)

# %%
def calc_PRF(tp,fp,fn):
    P = tp/float(tp+fp)
    R= tp/float(tp+fn)
    if tp ==0:
        return P,R,0
    return (P,R,2.*P*R/(P+R))

# %%
[0, 0] in np.argwhere(np.zeros((2,2))%2==0)
# Out:
# True

# %%
zeros = np.argwhere(d[50:400,20:500]==0)
zeros
# Out:
# array([[  0, 411],
#        [  0, 412],
#        [  0, 413],
#        ...,
#        [349, 436],
#        [349, 437],
#        [349, 438]])

# %%
non_zeros = np.argwhere(d[50:400,20:500]!=0)
non_zeros
# Out:
# array([[  0,   0],
#        [  0,   1],
#        [  0,   2],
#        ...,
#        [349, 477],
#        [349, 478],
#        [349, 479]])

# %%
norm[non_zeros[:,0],non_zeros[:,1]]
# Out:
# array([  59.85286973,   58.02597186,   59.85286973, ...,  115.00607415,
#         116.0685625 ,  116.0685625 ])

# %%
norm = angle_from_normal(convert_rgb_normal(n[50:400,20:500]))
norm[-1][-1]
# Out:
# 116.0685624984061

# %%
z = np.take(norm,zeros)[:,0]

# %%
z1 = np.take(norm,non_zeros)[:,0]

# %%
def plot_hist(path,num_params=50,start=2,end=3000,file_digits=10):
        params = np.linspace(0,1,num_params)
        data = dict.fromkeys(params,0)
        data_tot = dict.fromkeys(params,0)
        len1=0
        len2=0
        for i in range(start,end+1):
            d,n,gt = get_images_short(i,file_digits,path)
            d= d[50:400,20:500]
            n = n[50:400,20:500]
            gt = gt[50:400,20:500]
            norm = ratio_from_normal(convert_rgb_normal(n))
            zeros = np.argwhere(d==0)
            len1+=len(zeros)
            zeros = np.array(filter(lambda x: gt[x[0],x[1]]<1200,zeros))
            len2+=len(zeros)
            z = norm[zeros[:,0],zeros[:,1]]
            h,w  = np.shape(norm)
            for i in range(h):
                for j in range(w):
                    if gt[i,j]<1200:
                        data_tot[params[(np.abs(params-norm[i,j])).argmin()]]+=1
            for i in z:
                data[params[(np.abs(params-i)).argmin()]]+=1
        vals= []
        for key in data.keys():
            vals.append(data[key]/float(data_tot[key]))
        plt.bar(data.keys(),vals,width=.01)
        return data,data_tot,len1,len2
a = plot_hist(path)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
vals=[]
for key in a[0].keys():
        vals.append(a[0][key]/float(a[1][key]))
plt.bar(a[0].keys(),vals,width=.01)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Container object of 50 artists>

# %%
def param_search(path,params,start=1,end=10,file_digits=10):
    param_scores = {}
    for p in params:
        print "param "+str(p)
        tp = 0
        fn = 0
        fp = 0
        for i in range(start,end+1):
            d,n,gt = get_images_short(i,file_digits,path)
            h,w = np.shape(d)
            d= d[50:400,20:500]
            n = n[50:400,20:500]
            gt = gt[50:400,20:500]
            norm = angle_from_normal(convert_rgb_normal(n))
            zeros = np.argwhere(d==0)
            non_zeros = np.argwhere(d!=0)
            z = norm[zeros[:,0],zeros[:,1]]
            z1 = norm[non_zeros[:,0],non_zeros[:,1]]
            true_pos = np.sum(z<p)
            f_pos = len(z)-true_pos
            tp += true_pos
            fn +=f_pos
            fp += np.sum(z1<p)
        print(tp,fn,fp)
        param_scores[round(np.nan_to_num(calc_PRF(tp,fp,fn))[0],5)] = p
    k = np.max(np.nan_to_num(param_scores.keys()))
    print np.nan_to_num(param_scores.keys())
    return param_scores[k],k

# %%
param_search(path,params=range(40,180))
# Out:
# param 40
# (1914, 128832, 54343)
# param 41
# (2137, 128609, 59586)
# param 42
# (2137, 128609, 59586)
# param 43
# (2137, 128609, 59586)
# param 44
# (2375, 128371, 64957)
# param 45
# (2375, 128371, 64957)
# param 46
# (2672, 128074, 70383)
# param 47
# (2672, 128074, 70383)
# param 48
# (2960, 127786, 75455)
# param 49
# (2960, 127786, 75455)
# param 50
# (2960, 127786, 75455)
# param 51
# (3278, 127468, 80365)
# param 52
# (3278, 127468, 80365)
# param 53
# (3658, 127088, 85766)
# param 54
# (3658, 127088, 85766)
# param 55
# (4055, 126691, 91933)
# param 56
# (4055, 126691, 91933)
# param 57
# (4488, 126258, 98010)
# param 58
# (4488, 126258, 98010)
# param 59
# (5029, 125717, 105141)
# param 60
# (5502, 125244, 112831)
# param 61
# (5502, 125244, 112831)
# param 62
# (5984, 124762, 121017)
# param 63
# (5984, 124762, 121017)
# param 64
# (6538, 124208, 131018)
# param 65
# (6538, 124208, 131018)
# param 66
# (7081, 123665, 142791)
# param 67
# (7750, 122996, 156722)
# param 68
# ...

# %%
def labeled_data_normals(path,start=1,end=10,file_digits=10,shuffle= True):
    x = []
    y = []
    num_pos=0
    for i in range(start,end+1):
        d,n,gt = get_images_short(i,file_digits,path)
        n = cre
        mask = create_depth_mask(gt,0,1000)
        d[~mask]=-1
        pos = np.argwhere(d==0)
        neg = np.argwhere(d!=0)[:len(pos)]
        
        data = map(lambda x: np.arccos(n[x[0],x[1]][2]),pos)
        x.extend(data)
        num_pos+=len(data)
        y.extend(np.ones(len(data)))
        
        data1 = map(lambda x: np.arccos(n[x[0],x[1]][2]),neg)
        x.extend(data1)
        y.extend(np.zeros(len(data1)))
        
    x,y = np.array(x),np.array(y)
    if shuffle:
        choices = np.random.choice(np.arange(len(x)),len(x)/100)  
        x,y = x[choices],y[choices]
    return x,y,num_pos

x,y,num = labeled_data_normals(path,1,200)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in arccos
#   if sys.path[0] == '':
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in arccos

# %%
(x!=np.nan).any()
# Out:
# True

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
clf = svm.SVC()
clf.fit(x, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
x_test,y_test,num_pos = labeled_data_normals(path,200,300)

# %%
clf.score(X=x_test,y=y_test)
# Out:
# 0.77960671674768012

# %%
def labeled_data(path,start=1,end=10,bounds=[100,400,100,500],file_digits=10):
    x = []
    y = []
    num_pos=0
    for i in range(start,end+1):
        d,c,s,r = get_images(i,file_digits,path)
        pos = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]==0)
        neg = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]!=0)[:len(pos)]
        
        data = map(lambda x: [s[x[0],x[1]]],pos)
        x.extend(data)
        num_pos+=len(data)
        y.extend([1]*len(data))
        
        data1 = map(lambda x: [s[x[0],x[1]]],neg)
        x.extend(data1)
        y.extend([0]*len(data1))  
    return x,y,num_pos

x,y,num_pos=labeled_data(path,1,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-264-62fb2e3fe47e> in <module>()
#      18     return x,y,num_pos
#      19
# ---> 20 x,y,num_pos=labeled_data(path,1,2)
#
# <ipython-input-264-62fb2e3fe47e> in labeled_data(path, start, end, bounds, file_digits)
#       4     num_pos=0
#       5     for i in range(start,end+1):
# ----> 6         d,c,s,r = get_images(i,file_digits,path)
#       7         pos = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]==0)
#       8         neg = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]!=0)[:len(pos)]
#
# ValueError: too many values to unpack

# %%
def labeled_data(path,start=1,end=10,bounds=[100,400,100,500],file_digits=10):
    x = []
    y = []
    num_pos=0
    for i in range(start,end+1):
        d,c,s,r = get_images(i,file_digits,path)
        pos = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]==0)
        neg = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]!=0)
        data = zip(r[pos][0][0],np.mean(s[pos][0][0],axis=1))
        x.extend(data)
        num_pos+=len(data)
        y.extend([1]*len(data))
        data1 = zip(r[neg][0][0],np.mean(s[neg][0][0],axis=1))
        x.extend(data1)
        y.extend([0]*len(data1))     
    return x,y,num_pos

x,y,num_pos=labeled_data(path,1)
len(x),len(y)
# Out:
# (12800, 12800)

# %%
def inspect(path,num_images=10,bounds=[100,400,100,500],file_digits=10):
    reflect = []
    shade = []
    for i in range(1,num_images+1):
        d,c,s,r = get_images(i,file_digits,path)
        index = np.argwhere(d[bounds[0]:bounds[1],bounds[2]:bounds[3]]==0)
        print r[index][0][0]
        reflect.append(r[index][0][0])
        shade.append(s[index][0][0])
    return reflect,shade

reflect,shade = inspect(path,2)

np.mean(reflect),np.mean(shade),np.std(reflect),np.std(shade)
# Out:
# [ 0.53333336  0.53333336  0.60784316  0.56862748  0.59215689  0.56862748
#   0.65882355  0.55686277  0.40784314  0.59607846  0.5411765   0.49019608
#   0.63921571  0.58431375  0.56862748  0.5411765   0.51372552  0.51372552
#   0.51764709  0.51764709  0.52549022  0.53725493  0.50980395  0.56470591
#   0.56078434  0.52549022  0.5529412   0.56078434  0.5411765   0.53333336
#   0.53333336  0.55686277  0.55686277  0.57647061  0.57647061  0.60000002
#   0.63921571  0.62352943  0.61960787  0.61960787  0.627451    0.62352943
#   0.60392159  0.66274512  0.65490198  0.63921571  0.62352943  0.65882355
#   0.62352943  0.66274512  0.66666669  0.64313728  0.64705884  0.63529414
#   0.627451    0.63529414  0.627451    0.65098041  0.60000002  0.59607846
#   0.58039218  0.68627453  0.69803923  0.7019608   0.71372551  0.63137257
#   0.627451    0.61176473  0.63137257  0.63529414  0.63529414  0.65098041
#   0.65098041  0.67450982  0.7019608   0.66274512  0.60392159  0.57254905
# ...

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.33, random_state=42)
clf = svm.SVC()
clf.fit(x, y)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
x_test,y_test,num_pos = labeled_data(path,3,4)

# %%
clf.score(X=x_test,y=y_test)
# Out:
# 0.5554059485530547

# %%
clf.predict(X=[[.4]])
# Out:
# array([0])

# %%
count1=0
count2=0
for i in range(len(x)):
    if x[i]>.8:
        if y[i]==1: count1+=1
        else: count2+=1
count1/float(count2)
# Out:
# 1.0

# %%
len(x),len(y)
# Out:
# (47450, 47450)
